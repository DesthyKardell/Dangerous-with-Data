# %%
import pandas as pd


file_path = "data/DATASET_Asthma_Chronic_Disease_Indicators.csv"
asthma_data = pd.read_csv(file_path)
asthma_data.head()
asthma_data.columns
asthma_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc            DataSource   Topic  \
# 0       2010     2010           AR     Arkansas  State Inpatient Data  Asthma
# 1       2010     2010           AR     Arkansas  State Inpatient Data  Asthma
# 2       2010     2010           AR     Arkansas  State Inpatient Data  Asthma
# 3       2010     2010           MD     Maryland  State Inpatient Data  Asthma
# 4       2010     2010           NE     Nebraska  State Inpatient Data  Asthma
#
#                       Question Response DataValueUnit DataValueTypeID  \
# 0  Hospitalizations for asthma      NaN           NaN            Nmbr
# 1  Hospitalizations for asthma      NaN           NaN            Nmbr
# 2  Hospitalizations for asthma      NaN           NaN            Nmbr
# 3  Hospitalizations for asthma      NaN           NaN            Nmbr
# 4  Hospitalizations for asthma      NaN           NaN            Nmbr
#
# ...

# %%
#extract useful columns
useful_cols_df = asthma_data[['YearStart', 'YearEnd','LocationDesc', 'Topic', 'DataValueType','Stratification1','Question', 'Response','DataValueUnit', 'DataValue', 'GeoLocation']]
useful_cols_df.head()
# Out:
#    YearStart  YearEnd LocationDesc   Topic DataValueType Stratification1  \
# 0       2010     2010     Arkansas  Asthma        Number          Female
# 1       2010     2010     Arkansas  Asthma        Number            Male
# 2       2010     2010     Arkansas  Asthma        Number         Overall
# 3       2010     2010     Maryland  Asthma        Number         Overall
# 4       2010     2010     Nebraska  Asthma        Number            Male
#
#                       Question Response DataValueUnit DataValue  \
# 0  Hospitalizations for asthma      NaN           NaN      1904
# 1  Hospitalizations for asthma      NaN           NaN       979
# 2  Hospitalizations for asthma      NaN           NaN      2885
# 3  Hospitalizations for asthma      NaN           NaN      9582
# 4  Hospitalizations for asthma      NaN           NaN       511
#
#                                GeoLocation
# 0  (34.74865012400045, -92.27449074299966)
# 1  (34.74865012400045, -92.27449074299966)
# ...

# %%
import numpy as np
useful_cols_df['DataValue'].replace('', np.nan, inplace=True)
useful_cols_df.dropna(subset=['DataValue'], inplace=True)
useful_cols_df.head(30)
udf=useful_cols_df
#useful_cols_df = useful_cols_df.dropna(how = 'all')
udf = udf.loc[udf['DataValueType'] == 'Number']
udf = udf.loc[udf['Stratification1'] == 'Overall']
 
#udf = udf.loc[udf['DataValueType'] == 'Asthma mortality rate']
udf = udf[udf['Question'].str.contains('Asthma mortality rate')]
#udf2 = udf[udf['Question'].str.contains('Emergency')]

#udf = udf[udf['Question'].str.contains('Asthma mortality rate|Emergency|Hospit')]
#udf = udf.loc[udf['Question'] == 'Emergency department visit rate for asthma']
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
udf
# Out:
#        YearStart  YearEnd   LocationDesc   Topic DataValueType  \
# 17          2012     2012    Connecticut  Asthma        Number
# 18          2013     2013    Connecticut  Asthma        Number
# 20          2014     2014    Connecticut  Asthma        Number
# 23          2014     2014         Kansas  Asthma        Number
# 25          2011     2011      Wisconsin  Asthma        Number
# 26          2012     2012      Wisconsin  Asthma        Number
# 27          2013     2013      Wisconsin  Asthma        Number
# 28          2014     2014      Wisconsin  Asthma        Number
# 557         2013     2013        Alabama  Asthma        Number
# 1377        2013     2013     California  Asthma        Number
# 2552        2014     2014     California  Asthma        Number
# 4190        2012     2012        Florida  Asthma        Number
# 4780        2010     2010         Alaska  Asthma        Number
# 4804        2011     2011         Alaska  Asthma        Number
# ...

# %%
#grp_daty_udf= udf.groupby('DataValueType')
#useful_cols_udf = udf[['YearStart', 'YearEnd','LocationDesc', 'Topic', 'Asthma mortality rate','Emergency department visit rate for asthma', 'Hospitalizations for asthma', 'Response','DataValueUnit', 'DataValue', 'GeoLocation']]
#grp_daty_udf.head()

#udf.pivot_table(values='DataValue',index=['YearStart','YearEnd','GeoLocation','LocationDesc','Topic', 'Response', 'DataValueUnit', 'GeoLocation'],
  #             columns=['Question', 'DataValueType'],aggfunc=np.mean)

# %%
#useful_cols_df.groupby(['YearStart','YearEnd','LocationDesc','DataValueType','Question']).mean()
#udf2 = udf.groupby('YearStart')['LocationDesc']['DataValue'].mean()
#udf.groupby(['YearStart', 'LocationDesc'])['DataValue'].apply(lambda x : x.astype(int).mean())

#udf3 = pd.DataFrame( udf.groupby(['YearStart', 'LocationDesc']).agg({'DataValue':sum}))
udf.pivot(index="LocationDesc",values="DataValue",columns="YearStart")
# Out:
# YearStart             2010  2011  2012  2013  2014
# LocationDesc
# Alabama                 61    36    57    42    57
# Alaska
# Arizona                 58    92    80    98    86
# Arkansas                37    46    30    36    33
# California             403   403   384   410   407
# Colorado                48    42    55    51    41
# Connecticut             45    24    39    36    36
# Delaware
# District of Columbia
# Florida                177   148   195   188   191
# Georgia                 97    96    93   101    96
# Hawaii                        26          24    24
# Idaho                   21          21    23    22
# Illinois               183   176   174   192   167
# Indiana                 69    73    72    69    73
# Iowa                    46    43    35    36    54
# Kansas                  33    25    26    32    27
# Kentucky                44    33    25    36    35
# Louisiana               36    37    40    56    61
# Maine
# ...
